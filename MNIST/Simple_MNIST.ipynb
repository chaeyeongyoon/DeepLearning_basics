# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import random

tf.set_random_seed(777) # for reproducibility

from tensorflow.examples.tutorials.mnist import input_data
# MNIST 불러오는 API

mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)

nb_classes = 10

# MNIST image shape (28, 28)
X = tf.placeholder(tf.float32, [None, 784])
Y = tf.placeholder(tf.float32, [None, nb_classes])

W = tf.Variable(tf.random_normal([784, nb_classes]))
b = tf.Variable(tf.random_normal([nb_classes]))

hypothesis = tf.nn.softmax(tf.matmul(X, W) + b)

cost = tf.reduce_mean(-tf.reduce_sum(Y * tf.log(hypothesis), axis=1))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# Test model
is_correct = tf.equal(tf.argmax(hypothesis, 1), tf.argmax(Y, 1))
# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(is_correct, tf.float32))

# parameters
num_epochs = 15
batch_size = 100
num_iterations = int(mnist.train.num_examples / batch_size)

with tf.Session() as sess:
    # Initialize TensorFlow variables
    sess.run(tf.global_variables_initializer())
    # Training cycle
    for epoch in range(num_epochs):
        avg_cost = 0

        for i in range(num_iterations):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size) # 차례로 100개의 trainig data 읽어짐
            _, cost_val = sess.run([train, cost], feed_dict={X: batch_xs, Y: batch_ys})
            avg_cost += cost_val / num_iterations

        print("Epoch: {:04d}, Cost: {:.9f}".format(epoch + 1, avg_cost))

    print("Learning finished")
    
    # accuracy.eval : sess.run()의 다른 형태
    print(
        'Accuracy:',
         accuracy.eval(
             session=sess, feed_dict={X:mnist.test.images, Y:mnist.test.labels}
         )
    )
    
    # Get one and predict
    r = random.randint(0, mnist.test.num_examples - 1)
    print('Label:', sess.run(tf.argmax(mnist.test.labels[r : r+1], 1)))
    print(
        'Prediction: ',
        sess.run(tf.argmax(hypothesis, 1), feed_dict={X:mnist.test.images[r:r+1]})
    )
    
    plt.imshow(mnist.test.images[r:r+1].reshape(28, 28),
               cmap='Greys', 
               interpolation='nearest')
    plt.show()
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# cost_val: 15.512838
# cost_val: 14.062937
# cost_val: 14.350136
# cost_val: 9.805599
# cost_val: 9.348984
# cost_val: 10.304163
# cost_val: 10.33081
# cost_val: 9.291607
# cost_val: 9.418029
# cost_val: 9.010619
# cost_val: 8.89382
# cost_val: 7.4318976
# cost_val: 6.6159377
# cost_val: 8.045719
# cost_val: 7.240769
# cost_val: 6.6881948
# cost_val: 6.9086637
# cost_val: 6.9209666
# cost_val: 6.963852
# cost_val: 6.0385175
# cost_val: 6.1745086
# cost_val: 6.483678
# cost_val: 6.124054
# cost_val: 5.611065
# cost_val: 6.8860755
# cost_val: 5.3378363
# cost_val: 4.4742994
# cost_val: 5.338222
# cost_val: 5.663321
# cost_val: 6.2506905
# cost_val: 5.9629946
# cost_val: 5.74426
# cost_val: 6.1299677
# cost_val: 5.735663
# cost_val: 5.5564656
# cost_val: 5.1480274
# cost_val: 5.312965
# cost_val: 5.5508633
# cost_val: 4.712282
# cost_val: 5.388216
# cost_val: 4.920579
# cost_val: 5.292822
# cost_val: 5.5322127
# cost_val: 5.325104
# cost_val: 5.246297
# cost_val: 5.1554737
# cost_val: 4.424248
# cost_val: 5.1449122
# cost_val: 3.8697236
# cost_val: 5.652428
# cost_val: 3.961217
# cost_val: 4.537527
# cost_val: 4.4329333
# cost_val: 4.6130996
# cost_val: 4.6122837
# cost_val: 4.725735
# cost_val: 4.2202435
# cost_val: 4.5530415
# cost_val: 4.132576
# cost_val: 5.029525
# cost_val: 4.5204744
# cost_val: 3.9899487
# cost_val: 4.1884165
# cost_val: 3.8424494
# cost_val: 4.320672
# cost_val: 4.7765565
# cost_val: 3.444107
# cost_val: 3.4263177
# cost_val: 4.434588
# cost_val: 3.6370587
# cost_val: 4.284609
# cost_val: 3.5017114
# cost_val: 2.6603186
# cost_val: 5.1353045
# cost_val: 3.6961868
# cost_val: 3.5141227
# cost_val: 3.4235284
# cost_val: 3.0368638
# cost_val: 3.837991
# cost_val: 3.5933638
# cost_val: 3.1325247
# cost_val: 4.3704515
# cost_val: 3.410477
# cost_val: 3.1672406
# cost_val: 3.5515628
# cost_val: 3.6533163
# cost_val: 2.946255
# cost_val: 3.5922852
# cost_val: 2.994769
# cost_val: 3.6011686
# cost_val: 3.2987216
# cost_val: 3.455148
# cost_val: 3.6791275
# cost_val: 4.099481
# cost_val: 2.949103
# cost_val: 4.0098157
# cost_val: 3.524922
# cost_val: 2.768533
# cost_val: 2.8456686
# cost_val: 3.1818326
# cost_val: 3.1622405
# cost_val: 2.7266703
# cost_val: 3.5277157
# cost_val: 3.793506
# cost_val: 3.5769742
# cost_val: 3.3611174
# cost_val: 3.4026232
# cost_val: 2.9700463
# cost_val: 3.2896242
# cost_val: 2.6155186
# cost_val: 4.385477
# cost_val: 2.3678691
# cost_val: 2.918297
# cost_val: 2.8534005
# cost_val: 3.0727072
# cost_val: 2.6912494
# cost_val: 3.6806762
# cost_val: 2.7276254
# cost_val: 2.776373
# cost_val: 2.704729
# cost_val: 2.4627347
# cost_val: 2.3329525
# cost_val: 2.6332495
# cost_val: 3.6637373
# cost_val: 3.3580673
# cost_val: 3.1551125
# cost_val: 2.4651475
# cost_val: 2.8449304
# cost_val: 3.4103742
# cost_val: 2.7376525
# cost_val: 3.714287
# cost_val: 2.7768607
# cost_val: 3.3128617
# cost_val: 3.1076694
# cost_val: 2.6737902
# cost_val: 2.1137843
# cost_val: 2.7585478
# cost_val: 2.5606012
# cost_val: 2.7239738
# cost_val: 3.2301145
# cost_val: 2.1848812
# cost_val: 2.8122702
# cost_val: 2.2585337
# cost_val: 2.4415061
# cost_val: 2.6018057
# cost_val: 2.9283788
# cost_val: 1.8851584
# cost_val: 2.5736773
# cost_val: 2.9850183
# cost_val: 2.1522577
# cost_val: 2.4545963
# cost_val: 2.8569064
# cost_val: 2.4727318
# cost_val: 3.0507445
# cost_val: 3.3613844
# cost_val: 2.941965
# cost_val: 2.853097
# cost_val: 3.170092
# cost_val: 2.8066468
# cost_val: 2.6494117
# cost_val: 2.519469
# cost_val: 1.9171373
# cost_val: 3.325026
# cost_val: 2.8439689
# cost_val: 2.1652617
# cost_val: 2.6969023
# cost_val: 1.9832518
# cost_val: 1.9696504
# cost_val: 2.0756605
# cost_val: 2.6938393
# cost_val: 2.354812
# cost_val: 2.6714957
# cost_val: 2.282612
# cost_val: 2.0644403
# cost_val: 2.556546
# cost_val: 2.4967895
# cost_val: 2.0533035
# cost_val: 2.5522346
# cost_val: 1.4490405
# cost_val: 2.0463147
# cost_val: 2.5743415
# cost_val: 2.0576594
# cost_val: 2.32892
# cost_val: 1.808245
# cost_val: 2.092804
# cost_val: 2.4733174
# cost_val: 2.0583432
# cost_val: 2.4367177
# cost_val: 1.7413679
# cost_val: 1.958974
# cost_val: 2.5377393
# cost_val: 2.039776
# cost_val: 2.3276217
# cost_val: 2.4494002
# cost_val: 2.4643426
# cost_val: 2.3522532
# cost_val: 1.431222
# cost_val: 2.079879
# cost_val: 2.4483864
# cost_val: 1.6688073
# cost_val: 2.428253
# cost_val: 2.2663753
# cost_val: 2.2171357
# cost_val: 1.9694821
# cost_val: 1.7204231
# cost_val: 2.2568717
# cost_val: 2.4357634
# cost_val: 1.9914038
# cost_val: 1.6280146
# cost_val: 2.2681177
# cost_val: 1.5853074
# cost_val: 1.5951451
# cost_val: 2.0575454
# cost_val: 2.828442
# cost_val: 2.6460378
# cost_val: 2.1138475
# cost_val: 2.1809044
# cost_val: 1.5899829
# cost_val: 2.8235366
# cost_val: 1.9058
# cost_val: 2.12527
# cost_val: 2.4148586
# cost_val: 1.99948
# cost_val: 1.8393255
# cost_val: 1.7732468
# cost_val: 1.7044202
# cost_val: 2.240569
# cost_val: 1.9817114
# cost_val: 1.700621
# cost_val: 2.1067007
# cost_val: 2.4176147
# cost_val: 2.4233494
# cost_val: 2.162443
# cost_val: 2.0686882
# cost_val: 1.6889522
# cost_val: 2.3298228
# cost_val: 1.4756746
# cost_val: 2.6792462
# cost_val: 2.5658834
# cost_val: 1.934555
# cost_val: 1.4771852
# cost_val: 1.070205
# cost_val: 1.8895208
# cost_val: 2.6047025
# cost_val: 2.998578
# cost_val: 1.5774591
# cost_val: 1.9745859
# cost_val: 1.386669
# cost_val: 1.9130828
# cost_val: 1.8033574
# cost_val: 2.261694
# cost_val: 2.6411932
# cost_val: 1.6384778
# cost_val: 1.821529
# cost_val: 1.259856
# cost_val: 1.6750876
# cost_val: 1.690712
# cost_val: 1.561209
# cost_val: 1.6361486
# cost_val: 2.174876
# cost_val: 1.7951629
# cost_val: 1.5525967
# cost_val: 2.2630801
# cost_val: 2.1525543
# cost_val: 1.8166745
# cost_val: 1.381266
# cost_val: 1.5621685
# cost_val: 1.2603611
# cost_val: 1.8287882
# cost_val: 1.308707
# cost_val: 2.3044384
# cost_val: 2.1912458
# cost_val: 1.7599369
# cost_val: 1.1149577
# cost_val: 2.118067
# cost_val: 1.3672413
# cost_val: 1.976343
# cost_val: 2.6244364
# cost_val: 1.4386133
# cost_val: 2.4019265
# cost_val: 1.520384
# cost_val: 1.8671681
# cost_val: 2.0325582
# cost_val: 1.3009022
# cost_val: 1.5776057
# cost_val: 1.932872
# cost_val: 1.6240152
# cost_val: 1.6324649
# cost_val: 1.8768251
# cost_val: 1.7786239
# cost_val: 1.8236227
# cost_val: 1.8655319
# cost_val: 1.3723807
# cost_val: 1.9679941
# cost_val: 1.4212637
# cost_val: 1.5518781
# cost_val: 1.4965843
# cost_val: 1.7641338
# cost_val: 1.5712132
# cost_val: 1.9670379
# cost_val: 1.8826665
# cost_val: 1.4262549
# cost_val: 2.1039248
# cost_val: 2.05725
# cost_val: 1.8640158
# cost_val: 1.9486935
# cost_val: 1.8160961
# cost_val: 2.0142808
# cost_val: 2.1416693
# cost_val: 1.559022
# cost_val: 1.9898999
# cost_val: 1.4703848
# cost_val: 1.7935103
# cost_val: 1.6402012
# cost_val: 1.8940551
# cost_val: 1.8709381
# cost_val: 1.9528536
# cost_val: 1.7542213
# cost_val: 1.4412863
# cost_val: 2.1133225
# cost_val: 2.4272437
# cost_val: 1.7692245
# cost_val: 2.2212641
# cost_val: 1.5526683
# cost_val: 1.8488829
# cost_val: 1.8453057
# cost_val: 1.451469
# cost_val: 1.2624311
# cost_val: 1.4155056
# cost_val: 1.9009236
# cost_val: 1.804863
# cost_val: 1.3578372
# cost_val: 1.5061095
# cost_val: 0.8227104
# cost_val: 1.6930565
# cost_val: 1.3362167
# cost_val: 1.8821003
# cost_val: 1.3616785
# cost_val: 2.1357682
# cost_val: 1.3143605
# cost_val: 1.8017792
# cost_val: 1.8863107
# cost_val: 1.4848578
# cost_val: 1.4087873
# cost_val: 1.3339294
# cost_val: 1.5408586
# cost_val: 1.982603
# cost_val: 1.4010653
# cost_val: 1.611113
# cost_val: 1.2131237
# cost_val: 1.9283508
# cost_val: 1.8965
# cost_val: 1.7991154
# cost_val: 1.2647027
# cost_val: 1.5446812
# cost_val: 1.6820679
# cost_val: 1.0195029
# cost_val: 1.5818292
# cost_val: 1.7892603
# cost_val: 1.8564682
# cost_val: 1.7605041
# cost_val: 1.1557499
# cost_val: 1.3738519
# cost_val: 1.1726193
# cost_val: 1.2354668
# cost_val: 1.1513991
# cost_val: 2.0950518
# cost_val: 2.1284707
# cost_val: 2.2430234
# cost_val: 1.7262818
# cost_val: 1.2536087
# cost_val: 1.3364247
# cost_val: 1.8138548
# cost_val: 1.5695283
# cost_val: 1.958894
# cost_val: 1.7717167
# cost_val: 1.0608752
# cost_val: 1.756538
# cost_val: 1.5377312
# cost_val: 1.4570614
# cost_val: 1.5784246
# cost_val: 1.6443704
# cost_val: 2.1055193
# cost_val: 1.3751427
# cost_val: 1.1449887
# cost_val: 1.4103479
# cost_val: 1.5438969
# cost_val: 1.9833972
# cost_val: 2.4592662
# cost_val: 1.1152983
# cost_val: 1.4649343
# cost_val: 1.1031965
# cost_val: 1.4272969
# cost_val: 1.7825695
# cost_val: 1.2554332
# cost_val: 1.3773481
# cost_val: 1.9932228
# cost_val: 1.2021265
# cost_val: 2.3873532
# cost_val: 1.5362713
# cost_val: 1.5320907
# cost_val: 1.5593776
# cost_val: 0.9579781
# cost_val: 1.3603516
# cost_val: 1.6498065
# cost_val: 1.738026
# cost_val: 1.4577376
# cost_val: 2.1339192
# cost_val: 1.5188239
# cost_val: 1.6798744
# cost_val: 2.0990703
# cost_val: 1.2737696
# cost_val: 2.0760682
# cost_val: 1.0501996
# cost_val: 1.2429426
# cost_val: 1.2988161
# cost_val: 1.999958
# cost_val: 1.7896003
# cost_val: 1.4369614
# cost_val: 1.1811528
# cost_val: 1.5718426
# cost_val: 1.3536241
# cost_val: 1.4356374
# cost_val: 1.1101872
# cost_val: 0.91652405
# cost_val: 1.7878352
# cost_val: 1.3996327
# cost_val: 1.3629007
# cost_val: 1.752613
# cost_val: 1.5919446
# cost_val: 1.429953
# cost_val: 1.4054245
# cost_val: 1.2934335
# cost_val: 1.1208091
# cost_val: 1.3476949
# cost_val: 1.9611368
# cost_val: 1.69218
# cost_val: 1.3471864
# cost_val: 1.5713457
# cost_val: 0.97629523
# cost_val: 1.4614038
# cost_val: 1.2496632
# cost_val: 1.2150875
# cost_val: 1.6173189
# cost_val: 1.1515732
# cost_val: 1.2329807
# cost_val: 1.8273021
# cost_val: 1.5172415
# cost_val: 1.3364886
# cost_val: 1.4722263
# cost_val: 1.5010093
# cost_val: 1.0182941
# cost_val: 0.8709904
# cost_val: 0.8611381
# cost_val: 1.7105505
# cost_val: 1.3723673
# cost_val: 0.89473796
# cost_val: 1.7436947
# cost_val: 1.7129875
# cost_val: 1.81196
# cost_val: 1.3591814
# cost_val: 1.0893902
# cost_val: 1.6284877
# cost_val: 1.5538315
# cost_val: 0.97505736
# cost_val: 1.4934253
# cost_val: 1.4640319
# cost_val: 1.1802634
# cost_val: 1.0486727
# cost_val: 1.7432411
# cost_val: 1.5563279
# cost_val: 1.483891
# cost_val: 1.594779
# cost_val: 1.4163395
# cost_val: 1.7039317
# cost_val: 1.3877428
# cost_val: 1.249383
# cost_val: 1.684299
# cost_val: 1.5645922
# cost_val: 1.1858488
# cost_val: 1.2006439
# cost_val: 1.1256647
# cost_val: 1.6678199
# cost_val: 1.5273979
# cost_val: 1.3714415
# cost_val: 1.2357816
# cost_val: 1.410293
# cost_val: 1.1687477
# cost_val: 1.5109941
# cost_val: 0.99574304
# cost_val: 1.9622765
# cost_val: 1.0828834
# cost_val: 1.4288316
# cost_val: 1.8818287
# cost_val: 0.9926865
# cost_val: 1.3723259
# cost_val: 1.5433084
# cost_val: 2.2957168
# cost_val: 1.5650668
# cost_val: 0.88405603
# cost_val: 1.2385544
# cost_val: 1.5134593
# cost_val: 1.2424779
# cost_val: 1.2896531
# cost_val: 1.1982317
# cost_val: 1.3299257
# cost_val: 1.0751565
# cost_val: 1.3175588
# cost_val: 1.7928758
# cost_val: 1.0977092
# cost_val: 1.3768452
# cost_val: 1.7907996
# cost_val: 1.8936174
# cost_val: 1.2866739
# cost_val: 1.0819479
# cost_val: 1.4338243
# cost_val: 1.2511775
# cost_val: 1.4823931
# cost_val: 1.1447892
# cost_val: 1.8817371
# cost_val: 1.0421433
# cost_val: 1.0281066
# cost_val: 0.9076514
# cost_val: 1.4537882
# cost_val: 1.6876415
# cost_val: 0.9161314
# cost_val: 1.1603124
# cost_val: 1.167436
# cost_val: 0.83120584
# cost_val: 1.3834631
# cost_val: 1.3968189
# cost_val: 1.0549296
# cost_val: 1.4682513
# cost_val: 0.8181613
# cost_val: 1.0550762
# cost_val: 1.3861052
# cost_val: 1.2999501
# cost_val: 1.2659723
# cost_val: 0.81224823
# cost_val: 1.3209827
# cost_val: 1.3036934
# cost_val: 1.7957778
# cost_val: 1.2613319
# cost_val: 1.3091806
# cost_val: 2.051999
# cost_val: 1.5872121
# cost_val: 0.8243787
# cost_val: 1.6594932
# cost_val: 1.0600343
# cost_val: 1.6166877
# Epoch: 0001, Cost: 2.486426467
# cost_val: 1.4550999
# cost_val: 1.2467358
# cost_val: 0.74621314
# cost_val: 1.076627
# cost_val: 1.3033241
# cost_val: 1.4411573
# cost_val: 1.5472485
# cost_val: 1.4348758
# cost_val: 1.243734
# cost_val: 1.3481586
# cost_val: 1.875705
# cost_val: 1.4622855
# cost_val: 1.7670609
# cost_val: 1.0344942
# cost_val: 0.9306298
# cost_val: 1.421251
# cost_val: 1.8696849
# cost_val: 1.2969836
# cost_val: 1.5310405
# cost_val: 1.3890905
# cost_val: 0.98190534
# cost_val: 1.4035797
# cost_val: 1.2952696
# cost_val: 1.1850369
# cost_val: 0.9880614
# cost_val: 1.1750809
# cost_val: 1.0573449
# cost_val: 1.207409
# cost_val: 1.7013192
# cost_val: 1.4554286
# cost_val: 1.480182
# cost_val: 1.2049621
# cost_val: 1.1404197
# cost_val: 1.0556746
# cost_val: 0.82098573
# cost_val: 1.3834465
# cost_val: 1.106704
# cost_val: 1.3552705
# cost_val: 1.0050279
# cost_val: 1.1844488
# cost_val: 1.1770128
# cost_val: 1.5292997
# cost_val: 1.0949794
# cost_val: 0.9444435
# cost_val: 0.8784334
# cost_val: 1.7219217
# cost_val: 1.5860258
# cost_val: 1.1533362
# cost_val: 1.1807936
# cost_val: 1.3974713
# cost_val: 1.6933714
# cost_val: 1.3410957
# cost_val: 1.45985
# cost_val: 1.0627091
# cost_val: 0.683622
# cost_val: 1.430153
# cost_val: 1.5252763
# cost_val: 1.1305549
# cost_val: 1.2589334
# cost_val: 1.3581607
# cost_val: 1.3221328
# cost_val: 1.1547116
# cost_val: 1.3297244
# cost_val: 0.6113069
# cost_val: 1.0318372
# cost_val: 1.8560895
# cost_val: 1.6240616
# cost_val: 1.1426191
# cost_val: 1.3750634
# cost_val: 1.3309159
# cost_val: 0.8677343
# cost_val: 0.69567734
# cost_val: 1.1110532
# cost_val: 1.1961206
# cost_val: 1.2623216
# cost_val: 1.0944573
# cost_val: 0.802978
# cost_val: 0.943321
# cost_val: 1.6111783
# cost_val: 1.1536181
# cost_val: 1.1772106
# cost_val: 1.5442815
# cost_val: 1.2077125
# cost_val: 1.0836974
# cost_val: 1.4546646
# cost_val: 1.6170738
# cost_val: 0.9770113
# cost_val: 1.0146652
# cost_val: 1.5659736
# cost_val: 1.5222925
# cost_val: 1.0338864
# cost_val: 1.1020379
# cost_val: 0.9624655
# cost_val: 1.8644474
# cost_val: 1.3485746
# cost_val: 1.180577
# cost_val: 1.410569
# cost_val: 0.94867355
# cost_val: 0.79813087
# cost_val: 1.2852533
# cost_val: 0.8035172
# cost_val: 1.2513951
# cost_val: 1.4303033
# cost_val: 1.0906488
# cost_val: 1.4293889
# cost_val: 1.5361588
# cost_val: 1.0389719
# cost_val: 0.9577063
# cost_val: 0.96781296
# cost_val: 1.2027953
# cost_val: 1.4070935
# cost_val: 0.9553612
# cost_val: 1.2755452
# cost_val: 1.1843424
# cost_val: 1.4937671
# cost_val: 1.2288737
# cost_val: 1.3045045
# cost_val: 1.0662603
# cost_val: 0.73917115
# cost_val: 1.3590564
# cost_val: 1.0257082
# cost_val: 1.5916817
# cost_val: 1.6350409
# cost_val: 1.2304528
# cost_val: 1.3455338
# cost_val: 1.2216374
# cost_val: 1.5576434
# cost_val: 0.7659591
# cost_val: 1.6845181
# cost_val: 1.4389203
# cost_val: 0.93518496
# cost_val: 1.0942255
# cost_val: 1.6137793
# cost_val: 1.4420952
# cost_val: 1.6648558
# cost_val: 1.1945195
# cost_val: 1.1860596
# cost_val: 1.3482032
# cost_val: 1.3177339
# cost_val: 1.23487
# cost_val: 1.6185439
# cost_val: 0.7533389
# cost_val: 1.5948143
# cost_val: 1.2091094
# cost_val: 1.0524884
# cost_val: 1.1908269
# cost_val: 1.5757314
# cost_val: 0.80560136
# cost_val: 0.6781193
# cost_val: 1.608646
# cost_val: 1.0548489
# cost_val: 1.2849357
# cost_val: 0.85105246
# cost_val: 1.0462341
# cost_val: 1.1432518
# cost_val: 1.2870462
# cost_val: 1.143362
# cost_val: 1.0456446
# cost_val: 0.78558135
# cost_val: 1.6854775
# cost_val: 1.4236822
# cost_val: 0.59412616
# cost_val: 1.2598251
# cost_val: 1.439432
# cost_val: 1.1267487
# cost_val: 1.4140413
# cost_val: 1.3650035
# cost_val: 1.0234925
# cost_val: 1.526609
# cost_val: 0.95470697
# cost_val: 0.8062534
# cost_val: 1.233001
# cost_val: 1.075857
# cost_val: 1.1983104
# cost_val: 1.0938054
# cost_val: 0.79896736
# cost_val: 1.3337066
# cost_val: 0.6709156
# cost_val: 0.95905465
# cost_val: 1.3479573
# cost_val: 1.14166
# cost_val: 0.7522218
# cost_val: 1.3476278
# cost_val: 1.3914669
# cost_val: 1.0665808
# cost_val: 1.3869876
# cost_val: 0.8463013
# cost_val: 1.0013229
# cost_val: 1.4315442
# cost_val: 0.9159382
# cost_val: 1.2545035
# cost_val: 1.1711209
# cost_val: 0.9596037
# cost_val: 1.3501515
# cost_val: 0.9931997
# cost_val: 1.1819361
# cost_val: 1.2114927
# cost_val: 0.81520003
# cost_val: 0.4847048
# cost_val: 1.4354836
# cost_val: 0.6921717
# cost_val: 1.1749307
# cost_val: 1.1871192
# cost_val: 1.0002165
# cost_val: 1.546067
# cost_val: 1.5565791
# cost_val: 0.9396206
# cost_val: 1.266715
# cost_val: 0.8356327
# cost_val: 1.0892909
# cost_val: 1.5673668
# cost_val: 0.90044785
# cost_val: 1.2489778
# cost_val: 1.3947122
# cost_val: 1.3247278
# cost_val: 1.1828501
# cost_val: 0.7883775
# cost_val: 1.2808855
# cost_val: 1.0929639
# cost_val: 0.97090936
# cost_val: 1.0424836
# cost_val: 1.1044513
# cost_val: 1.3048227
# cost_val: 1.1986015
# cost_val: 0.96050966
# cost_val: 1.2469012
# cost_val: 1.1867576
# cost_val: 1.2576966
# cost_val: 1.120365
# cost_val: 0.7818706
# cost_val: 1.1837093
# cost_val: 0.8356813
# cost_val: 0.64900976
# cost_val: 1.4935907
# cost_val: 1.1087978
# cost_val: 0.8375222
# cost_val: 0.5214752
# cost_val: 0.91034585
# cost_val: 0.684658
# cost_val: 0.5530564
# cost_val: 1.432166
# cost_val: 0.88667375
# cost_val: 1.2673389
# cost_val: 0.9479504
# cost_val: 1.22015
# cost_val: 1.1906099
# cost_val: 1.1699882
# cost_val: 1.1901419
# cost_val: 1.0071532
# cost_val: 0.76144415
# cost_val: 1.7233471
# cost_val: 0.7173434
# cost_val: 1.7811354
# cost_val: 0.8744438
# cost_val: 1.0390283
# cost_val: 1.1877451
# cost_val: 1.0557091
# cost_val: 1.3688108
# cost_val: 1.139196
# cost_val: 0.895285
# cost_val: 0.8162853
# cost_val: 1.1262814
# cost_val: 0.9983077
# cost_val: 1.1328359
# cost_val: 1.8345298
# cost_val: 1.3830522
# cost_val: 0.9578176
# cost_val: 0.9389378
# cost_val: 1.3603631
# cost_val: 0.85588264
# cost_val: 1.6576462
# cost_val: 0.8466637
# cost_val: 0.9861186
# cost_val: 1.2012886
# cost_val: 0.59144956
# cost_val: 1.0996945
# cost_val: 1.2073236
# cost_val: 0.92328805
# cost_val: 0.8547382
# cost_val: 0.75027466
# cost_val: 1.2493929
# cost_val: 0.73411804
# cost_val: 0.94860536
# cost_val: 1.3408946
# cost_val: 0.73537755
# cost_val: 0.9205682
# cost_val: 0.6048357
# cost_val: 1.6668804
# cost_val: 0.84091234
# cost_val: 0.9084356
# cost_val: 0.7361891
# cost_val: 1.1153307
# cost_val: 1.0658642
# cost_val: 1.1808269
# cost_val: 1.2358441
# cost_val: 0.6898724
# cost_val: 1.1098775
# cost_val: 0.92424464
# cost_val: 1.9498239
# cost_val: 1.426021
# cost_val: 1.0002552
# cost_val: 0.9926627
# cost_val: 1.0026103
# cost_val: 0.88457435
# cost_val: 0.902804
# cost_val: 0.9572331
# cost_val: 1.0610703
# cost_val: 0.8533227
# cost_val: 0.9093952
# cost_val: 0.6603557
# cost_val: 0.9473651
# cost_val: 0.9422853
# cost_val: 1.8405131
# cost_val: 0.9178308
# cost_val: 0.5224839
# cost_val: 0.8543427
# cost_val: 1.30068
# cost_val: 1.2392167
# cost_val: 1.1311299
# cost_val: 0.96253663
# cost_val: 1.1413736
# cost_val: 1.0812907
# cost_val: 1.2749264
# cost_val: 0.99836457
# cost_val: 0.5517125
# cost_val: 1.2502078
# cost_val: 1.0469761
# cost_val: 1.0597572
# cost_val: 0.9419777
# cost_val: 1.3060898
# cost_val: 1.7381225
# cost_val: 0.9664679
# cost_val: 1.4446331
# cost_val: 0.8283583
# cost_val: 1.4962882
# cost_val: 1.5697931
# cost_val: 1.0392123
# cost_val: 0.77667373
# cost_val: 1.000835
# cost_val: 0.7038744
# cost_val: 0.86755806
# cost_val: 1.0901384
# cost_val: 1.1904348
# cost_val: 1.5251466
# cost_val: 0.89411706
# cost_val: 0.8083532
# cost_val: 1.2199554
# cost_val: 1.6575886
# cost_val: 0.8258672
# cost_val: 0.7888763
# cost_val: 1.4910649
# cost_val: 1.1556044
# cost_val: 1.0200101
# cost_val: 0.9615477
# cost_val: 0.8317543
# cost_val: 1.066739
# cost_val: 0.8518325
# cost_val: 0.85284543
# cost_val: 1.1488369
# cost_val: 0.9267581
# cost_val: 1.0358778
# cost_val: 1.5661747
# cost_val: 1.2906476
# cost_val: 1.5773377
# cost_val: 1.0385119
# cost_val: 1.064083
# cost_val: 1.3854495
# cost_val: 1.1305367
# cost_val: 1.189595
# cost_val: 0.9373531
# cost_val: 1.0990504
# cost_val: 1.1378005
# cost_val: 1.0471447
# cost_val: 0.9674473
# cost_val: 1.1266723
# cost_val: 1.0338445
# cost_val: 0.8096226
# cost_val: 1.4323587
# cost_val: 0.9209629
# cost_val: 1.3555144
# cost_val: 1.1879927
# cost_val: 0.8923283
# cost_val: 1.5718006
# cost_val: 0.93612427
# cost_val: 1.0141672
# cost_val: 0.988462
# cost_val: 1.1347741
# cost_val: 1.240373
# cost_val: 1.0992509
# cost_val: 0.8769746
# cost_val: 0.86931777
# cost_val: 0.8902726
# cost_val: 0.9050772
# cost_val: 1.0697628
# cost_val: 0.76733035
# cost_val: 0.70233655
# cost_val: 0.6735671
# cost_val: 0.68704355
# cost_val: 1.1843549
# cost_val: 0.6550682
# cost_val: 1.1759776
# cost_val: 1.1508486
# cost_val: 0.871284
# cost_val: 1.043604
# cost_val: 1.0443968
# cost_val: 1.2428565
# cost_val: 1.2426358
# cost_val: 1.0926883
# cost_val: 0.83214194
# cost_val: 0.8251452
# cost_val: 0.93901944
# cost_val: 0.60280275
# cost_val: 1.0628192
# cost_val: 0.64146745
# cost_val: 0.8065994
# cost_val: 0.8984896
# cost_val: 1.5003406
# cost_val: 0.9909592
# cost_val: 0.8544681
# cost_val: 1.2353249
# cost_val: 1.1169765
# cost_val: 0.74301916
# cost_val: 1.3671836
# cost_val: 0.9488647
# cost_val: 1.4615666
# cost_val: 0.93686
# cost_val: 0.8695061
# cost_val: 1.3633536
# cost_val: 0.6574558
# cost_val: 1.3969272
# cost_val: 0.6987084
# cost_val: 0.95019966
# cost_val: 0.8309283
# cost_val: 0.88589454
# cost_val: 1.5307324
# cost_val: 1.0766368
# cost_val: 0.90763444
# cost_val: 0.7415782
# cost_val: 0.54876107
# cost_val: 1.210999
# cost_val: 1.6400746
# cost_val: 1.0663152
# cost_val: 0.7137719
# cost_val: 1.6764135
# cost_val: 0.6962294
# cost_val: 0.8255638
# cost_val: 0.84075713
# cost_val: 1.096318
# cost_val: 1.5012556
# cost_val: 1.3025731
# cost_val: 0.911745
# cost_val: 0.6558479
# cost_val: 1.1667006
# cost_val: 0.99474597
# cost_val: 0.9309035
# cost_val: 1.1786575
# cost_val: 1.0812256
# cost_val: 1.273422
# cost_val: 1.0701175
# cost_val: 0.84655607
# cost_val: 0.64238304
# cost_val: 1.234457
# cost_val: 0.57488203
# cost_val: 0.5585881
# cost_val: 0.89495885
# cost_val: 1.3979623
# cost_val: 0.78172463
# cost_val: 0.63476676
# cost_val: 1.2511187
# cost_val: 1.2305003
# cost_val: 1.0477281
# cost_val: 0.9025309
# cost_val: 0.67870295
# cost_val: 0.99346143
# cost_val: 1.0734749
# cost_val: 1.1093966
# cost_val: 0.6571031
# cost_val: 0.8704248
# cost_val: 0.9080046
# cost_val: 1.171024
# cost_val: 1.1687721
# cost_val: 1.0146358
# cost_val: 1.319448
# cost_val: 1.4608403
# cost_val: 1.1606869
# cost_val: 0.66276777
# cost_val: 0.7724814
# cost_val: 0.9113911
# cost_val: 0.69463676
# cost_val: 0.66894454
# cost_val: 0.81870425
# cost_val: 1.2451491
# cost_val: 1.0221289
# cost_val: 0.88598824
# cost_val: 0.81698644
# cost_val: 1.2135564
# cost_val: 1.3968142
# cost_val: 0.7032589
# cost_val: 0.7161288
# cost_val: 1.2003311
# cost_val: 0.664863
# cost_val: 1.3537592
# cost_val: 0.68804383
# cost_val: 0.99629813
# cost_val: 0.8381107
# cost_val: 1.3316551
# cost_val: 1.0077524
# cost_val: 0.51271164
# cost_val: 0.8409034
# cost_val: 1.0473105
# cost_val: 1.2727517
# cost_val: 1.0631624
# cost_val: 0.81306976
# cost_val: 0.92705476
# cost_val: 1.0620236
# cost_val: 1.3238297
# cost_val: 0.93456507
# cost_val: 1.3455036
# cost_val: 0.84080964
# cost_val: 0.8600531
# cost_val: 1.4297835
# cost_val: 1.170628
# cost_val: 1.2636863
# cost_val: 1.1171077
# cost_val: 0.7816855
# cost_val: 1.0643237
# cost_val: 1.2716163
# cost_val: 1.1174827
# cost_val: 1.361248
# cost_val: 1.2221859
# cost_val: 1.0708134
# cost_val: 0.78521764
# cost_val: 1.0823472
# cost_val: 0.9456522
# cost_val: 1.1964047
# cost_val: 0.8852414
# cost_val: 1.0528214
# cost_val: 1.174583
# cost_val: 1.3256685
# cost_val: 1.1728773
# cost_val: 0.7144584
# cost_val: 1.1989192
# cost_val: 1.0114167
# cost_val: 0.88167906
# cost_val: 1.3675057
# cost_val: 0.90462714
# cost_val: 0.943552
# cost_val: 0.9928934
# cost_val: 1.0553964
# cost_val: 1.4098701
# Epoch: 0002, Cost: 1.112299733
# cost_val: 1.0698398
# cost_val: 1.290349
# cost_val: 0.99784166
# cost_val: 0.92269045
# cost_val: 1.0721228
# cost_val: 0.7597695
# cost_val: 0.752714
# cost_val: 0.9980465
# cost_val: 0.96686804
# cost_val: 0.64087605
# cost_val: 0.67427945
# cost_val: 1.030588
# cost_val: 1.1717308
# cost_val: 0.6552122
# cost_val: 0.78483474
# cost_val: 1.1346217
# cost_val: 0.8824319
# cost_val: 1.0112929
# cost_val: 1.124852
# cost_val: 0.83711517
# cost_val: 0.63795406
# cost_val: 0.5034253
# cost_val: 0.67133164
# cost_val: 0.8639556
# cost_val: 0.693724
# cost_val: 1.0016387
# cost_val: 0.77875364
# cost_val: 0.51720494
# cost_val: 0.868591
# cost_val: 0.81238794
# cost_val: 0.65584165
# cost_val: 0.7802429
# cost_val: 0.96781576
# cost_val: 0.9191052
# cost_val: 1.1516504
# cost_val: 1.0892907
# cost_val: 0.752166
# cost_val: 1.1448213
# cost_val: 1.3134682
# cost_val: 0.82506907
# cost_val: 0.36907142
# cost_val: 0.8164402
# cost_val: 1.4347686
# cost_val: 1.1520283
# cost_val: 0.8448431
# cost_val: 0.75622976
# cost_val: 1.0560081
# cost_val: 0.70747304
# cost_val: 0.594626
# cost_val: 0.9972152
# cost_val: 0.95771515
# cost_val: 0.81494606
# cost_val: 1.0981174
# cost_val: 0.9177966
# cost_val: 0.6189716
# cost_val: 1.1464399
# cost_val: 1.301784
# cost_val: 0.68449885
# cost_val: 0.8307941
# cost_val: 1.4130332
# cost_val: 1.0318283
# cost_val: 0.43269348
# cost_val: 0.7191345
# cost_val: 0.9318402
# cost_val: 0.9270627
# cost_val: 1.4477283
# cost_val: 0.78843355
# cost_val: 0.6335455
# cost_val: 0.64887065
# cost_val: 1.4688774
# cost_val: 0.6863425
# cost_val: 1.1952728
# cost_val: 0.9912641
# cost_val: 0.86980194
# cost_val: 1.1928707
# cost_val: 1.1902767
# cost_val: 1.2837044
# cost_val: 0.8766433
# cost_val: 0.9238837
# cost_val: 1.0490959
# cost_val: 0.7529957
# cost_val: 0.96429014
# cost_val: 1.0262307
# cost_val: 0.79450333
# cost_val: 0.6545932
# cost_val: 0.7806211
# cost_val: 0.7872262
# cost_val: 1.2570951
# cost_val: 0.82299507
# cost_val: 1.1182432
# cost_val: 0.9885778
# cost_val: 0.83505
# cost_val: 0.776014
# cost_val: 1.0469283
# cost_val: 1.382638
# cost_val: 1.0831437
# cost_val: 0.7971003
# cost_val: 1.1143346
# cost_val: 1.0539088
# cost_val: 0.5408367
# cost_val: 0.89140296
# cost_val: 1.0323085
# cost_val: 0.7896712
# cost_val: 0.823491
# cost_val: 1.2771803
# cost_val: 1.4075446
# cost_val: 1.2829834
# cost_val: 1.0480901
# cost_val: 1.5747237
# cost_val: 1.7335697
# cost_val: 1.0306453
# cost_val: 1.0467541
# cost_val: 0.95721334
# cost_val: 0.59066194
# cost_val: 0.54660183
# cost_val: 0.7742753
# cost_val: 0.9677258
# cost_val: 1.2632389
# cost_val: 1.0829092
# cost_val: 0.68717355
# cost_val: 0.6904771
# cost_val: 0.8446787
# cost_val: 1.4694539
# cost_val: 1.1710596
# cost_val: 0.94958246
# cost_val: 1.3026134
# cost_val: 0.7100336
# cost_val: 1.1374544
# cost_val: 1.1936716
# cost_val: 0.7804692
# cost_val: 0.7213337
# cost_val: 0.6028879
# cost_val: 1.0403696
# cost_val: 0.6649878
# cost_val: 1.2433038
# cost_val: 0.7369574
# cost_val: 0.81936336
# cost_val: 0.77443475
# cost_val: 1.2962325
# cost_val: 1.1135753
# cost_val: 1.36372
# cost_val: 0.8426737
# cost_val: 1.2336977
# cost_val: 1.4501576
# cost_val: 1.0446681
# cost_val: 0.9265412
# cost_val: 0.93599725
# cost_val: 1.1658216
# cost_val: 1.0061536
# cost_val: 0.5775792
# cost_val: 0.95519173
# cost_val: 1.2317102
# cost_val: 0.9065262
# cost_val: 1.1126838
# cost_val: 0.7325
# cost_val: 1.045971
# cost_val: 1.2255795
# cost_val: 0.7122723
# cost_val: 0.847747
# cost_val: 0.68427247
# cost_val: 0.7651313
# cost_val: 0.8739933
# cost_val: 0.528932
# cost_val: 0.67103714
# cost_val: 1.1090606
# cost_val: 0.9752617
# cost_val: 0.6090573
# cost_val: 0.65516394
# cost_val: 0.8503834
# cost_val: 0.8847841
# cost_val: 1.0248796
# cost_val: 0.682688
# cost_val: 1.3720399
# cost_val: 1.2753218
# cost_val: 1.154364
# cost_val: 0.76193154
# cost_val: 1.0485679
# cost_val: 1.162341
# cost_val: 1.4684161
# cost_val: 0.64778537
# cost_val: 1.1630939
# cost_val: 0.7578333
# cost_val: 1.3807358
# cost_val: 0.5940607
# cost_val: 0.60427713
# cost_val: 1.0702415
# cost_val: 0.69802684
# cost_val: 1.1336628
# cost_val: 1.0638831
# cost_val: 0.86985505
# cost_val: 1.0849745
# cost_val: 0.5928081
# cost_val: 0.62372535
# cost_val: 0.9903908
# cost_val: 0.9847676
# cost_val: 0.61390513
# cost_val: 1.0070661
# cost_val: 0.78123504
# cost_val: 0.48564962
# cost_val: 0.899492
# cost_val: 0.8031805
# cost_val: 0.83260375
# cost_val: 1.0087974
# cost_val: 0.9553865
# cost_val: 0.57077616
# cost_val: 0.7828129
# cost_val: 0.51240015
# cost_val: 0.59427476
# cost_val: 0.72259355
# cost_val: 0.9369918
# cost_val: 0.8740679
# cost_val: 0.9540001
# cost_val: 1.0776266
# cost_val: 0.87624365
# cost_val: 1.0458366
# cost_val: 0.95258975
# cost_val: 0.74835914
# cost_val: 0.5307895
# cost_val: 0.8492677
# cost_val: 0.46834266
# cost_val: 1.2696958
# cost_val: 0.5395074
# cost_val: 0.9223281
# cost_val: 1.1379895
# cost_val: 1.012572
# cost_val: 1.0959797
# cost_val: 0.68291044
# cost_val: 1.2280955
# cost_val: 1.1034981
# cost_val: 0.72030365
# cost_val: 1.0067687
# cost_val: 0.889826
# cost_val: 0.7314355
# cost_val: 0.8276819
# cost_val: 0.6329629
# cost_val: 0.7345532
# cost_val: 1.0454843
# cost_val: 1.1108204
# cost_val: 0.8916408
# cost_val: 0.7140642
# cost_val: 0.86713105
# cost_val: 0.7971891
# cost_val: 0.56261206
# cost_val: 0.6719052
# cost_val: 0.5561288
# cost_val: 0.78657836
# cost_val: 0.586285
# cost_val: 0.78343666
# cost_val: 0.5801706
# cost_val: 1.0250903
# cost_val: 0.83789337
# cost_val: 0.6882297
# cost_val: 1.2207943
# cost_val: 1.1289668
# cost_val: 0.8723233
# cost_val: 0.6104364
# cost_val: 0.892755
# cost_val: 1.0679096
# cost_val: 0.8960109
# cost_val: 0.74739146
# cost_val: 0.6285005
# cost_val: 1.1013738
# cost_val: 0.9053102
# cost_val: 1.1564676
# cost_val: 0.79534566
# cost_val: 0.7958474
# cost_val: 0.78365797
# cost_val: 1.7432445
# cost_val: 1.3159633
# cost_val: 1.2328956
# cost_val: 0.73021585
# cost_val: 1.4113041
# cost_val: 1.2515786
# cost_val: 0.65674347
# cost_val: 1.0332524
# cost_val: 1.4943575
# cost_val: 0.4939815
# cost_val: 0.5598113
# cost_val: 0.88930327
# cost_val: 0.6010071
# cost_val: 0.72707677
# cost_val: 0.8278677
# cost_val: 0.70093805
# cost_val: 0.7243323
# cost_val: 1.0245333
# cost_val: 0.5476191
# cost_val: 0.9498371
# cost_val: 0.8533977
# cost_val: 0.7434281
# cost_val: 0.91305786
# cost_val: 0.65307844
# cost_val: 1.246176
# cost_val: 1.1126525
# cost_val: 0.55282855
# cost_val: 1.0631062
# cost_val: 1.007775
# cost_val: 0.9594511
# cost_val: 0.91011214
# cost_val: 1.0137454
# cost_val: 0.99168503
# cost_val: 0.82250655
# cost_val: 0.8732201
# cost_val: 1.2782253
# cost_val: 0.9828537
# cost_val: 0.7643449
# cost_val: 0.77541816
# cost_val: 0.77490157
# cost_val: 0.74140567
# cost_val: 0.23279732
# cost_val: 0.94065267
# cost_val: 0.95672435
# cost_val: 0.8927782
# cost_val: 0.8439553
# cost_val: 1.0140873
# cost_val: 0.9003911
# cost_val: 0.334109
# cost_val: 1.1065542
# cost_val: 0.89407927
# cost_val: 0.9208649
# cost_val: 0.36742988
# cost_val: 0.8376588
# cost_val: 1.0263587
# cost_val: 1.0961182
# cost_val: 1.3701004
# cost_val: 0.71729034
# cost_val: 0.833214
# cost_val: 0.9450839
# cost_val: 1.4429765
# cost_val: 0.95122147
# cost_val: 0.56658053
# cost_val: 1.1477821
# cost_val: 0.7152914
# cost_val: 0.9478184
# cost_val: 1.0745993
# cost_val: 0.74439317
# cost_val: 1.5465372
# cost_val: 0.900716
# cost_val: 0.9023789
# cost_val: 0.91662526
# cost_val: 1.1569111
# cost_val: 1.1811241
# cost_val: 0.6975046
# cost_val: 0.5961054
# cost_val: 1.1065984
# cost_val: 0.8196732
# cost_val: 1.456222
# cost_val: 0.9521873
# cost_val: 0.9152472
# cost_val: 1.0248219
# cost_val: 0.82315725
# cost_val: 1.4020572
# cost_val: 0.9400431
# cost_val: 0.9563801
# cost_val: 0.53001666
# cost_val: 0.88804835
# cost_val: 0.64013535
# cost_val: 0.73387766
# cost_val: 1.3639693
# cost_val: 0.8692747
# cost_val: 1.2038236
# cost_val: 1.1949002
# cost_val: 0.83750606
# cost_val: 0.7203014
# cost_val: 0.7548545
# cost_val: 1.1744238
# cost_val: 0.7748007
# cost_val: 1.2657151
# cost_val: 0.85766244
# cost_val: 0.44525895
# cost_val: 0.6143842
# cost_val: 1.1530061
# cost_val: 0.6658955
# cost_val: 1.0524988
# cost_val: 0.97223604
# cost_val: 0.7967469
# cost_val: 1.1252731
# cost_val: 0.63551503
# cost_val: 0.8996214
# cost_val: 1.1803104
# cost_val: 1.2926347
# cost_val: 1.1698593
# cost_val: 1.0910089
# cost_val: 0.99520093
# cost_val: 0.6413478
# cost_val: 0.70033723
# cost_val: 0.9637285
# cost_val: 1.1670765
# cost_val: 0.8749979
# cost_val: 0.65848005
# cost_val: 0.6326339
# cost_val: 0.4297677
# cost_val: 1.2441372
# cost_val: 0.56095546
# cost_val: 1.1204742
# cost_val: 0.7074492
# cost_val: 0.9826464
# cost_val: 0.7174092
# cost_val: 1.2184367
# cost_val: 1.430543
# cost_val: 0.87627107
# cost_val: 1.0836443
# cost_val: 1.1325608
# cost_val: 0.8779875
# cost_val: 0.44763556
# cost_val: 0.9009254
# cost_val: 0.8211235
# cost_val: 0.71543103
# cost_val: 1.0194786
# cost_val: 0.9019926
# cost_val: 0.9621021
# cost_val: 1.1442086
# cost_val: 1.1551243
# cost_val: 0.7846341
# cost_val: 0.8132046
# cost_val: 0.90510225
# cost_val: 0.7563202
# cost_val: 1.112547
# cost_val: 0.67277855
# cost_val: 1.073432
# cost_val: 0.58688337
# cost_val: 0.6821862
# cost_val: 0.96039337
# cost_val: 0.677535
# cost_val: 0.61567026
# cost_val: 0.5039539
# cost_val: 0.63304037
# cost_val: 0.6354203
# cost_val: 0.8893361
# cost_val: 0.44074205
# cost_val: 0.83125544
# cost_val: 1.0930759
# cost_val: 0.8711126
# cost_val: 1.0998398
# cost_val: 0.9511694
# cost_val: 0.8358914
# cost_val: 0.729989
# cost_val: 0.94556403
# cost_val: 0.52105045
# cost_val: 1.2281369
# cost_val: 0.93214965
# cost_val: 0.6116804
# cost_val: 0.78276795
# cost_val: 0.66565806
# cost_val: 0.95573556
# cost_val: 0.71970534
# cost_val: 1.0928768
# cost_val: 0.6867723
# cost_val: 1.0701352
# cost_val: 0.74326634
# cost_val: 0.5767866
# cost_val: 0.86022896
# cost_val: 0.6994743
# cost_val: 0.73368126
# cost_val: 0.9142635
# cost_val: 0.5142644
# cost_val: 0.71624964
# cost_val: 1.2627031
# cost_val: 1.1890941
# cost_val: 0.6947916
# cost_val: 0.80221945
# cost_val: 0.7927612
# cost_val: 0.7802025
# cost_val: 0.40602267
# cost_val: 0.83775926
# cost_val: 0.5408032
# cost_val: 0.7771977
# cost_val: 0.5498156
# cost_val: 0.911765
# cost_val: 0.95693946
# cost_val: 1.0560459
# cost_val: 0.4753592
# cost_val: 0.9275558
# cost_val: 0.78676504
# cost_val: 0.8836397
# cost_val: 0.42462394
# cost_val: 0.767614
# cost_val: 0.96562463
# cost_val: 0.96914274
# cost_val: 1.0755358
# cost_val: 0.6628637
# cost_val: 0.6606199
# cost_val: 0.4054948
# cost_val: 0.7932058
# cost_val: 0.9012509
# cost_val: 1.2810043
# cost_val: 0.9108903
# cost_val: 1.0134733
# cost_val: 1.1415259
# cost_val: 0.8381485
# cost_val: 0.7757833
# cost_val: 1.1450088
# cost_val: 0.7793995
# cost_val: 0.6993951
# cost_val: 0.7716542
# cost_val: 0.7098948
# cost_val: 1.0966141
# cost_val: 1.0588868
# cost_val: 1.3908156
# cost_val: 0.656466
# cost_val: 0.86664534
# cost_val: 0.8154942
# cost_val: 0.6010857
# cost_val: 0.7611649
# cost_val: 0.7586597
# cost_val: 0.768025
# cost_val: 0.94404197
# cost_val: 1.092582
# cost_val: 0.57995385
# cost_val: 0.5374416
# cost_val: 1.2347306
# cost_val: 0.6488427
# cost_val: 0.89474887
# cost_val: 0.6603341
# cost_val: 0.38598138
# cost_val: 1.1366627
# cost_val: 1.2062515
# cost_val: 0.7348578
# cost_val: 0.77381647
# cost_val: 1.0143914
# cost_val: 0.81911844
# cost_val: 0.996528
# cost_val: 0.9960883
# cost_val: 1.1352022
# cost_val: 0.9155842
# cost_val: 0.9154747
# cost_val: 0.73231125
# cost_val: 1.1767828
# cost_val: 1.2411188
# cost_val: 0.4992486
# cost_val: 0.9929687
# cost_val: 0.65678847
# cost_val: 0.8378615
# cost_val: 0.6516549
# cost_val: 1.5340686
# cost_val: 0.8066292
# cost_val: 0.41558346
# cost_val: 1.1217186
# cost_val: 0.8219395
# cost_val: 0.8358238
# cost_val: 0.71747345
# cost_val: 0.8011648
# cost_val: 0.4071444
# cost_val: 0.86346674
# cost_val: 0.89134157
# cost_val: 0.6569578
# cost_val: 0.73025733
# cost_val: 0.54808706
# cost_val: 0.6739546
# cost_val: 0.3310596
# cost_val: 0.4417734
# Epoch: 0003, Cost: 0.894773326
# cost_val: 1.008573
# cost_val: 0.82398194
# cost_val: 0.5078048
# cost_val: 0.8369385
# cost_val: 0.85432607
# cost_val: 0.574386
# cost_val: 1.2235528
# cost_val: 0.5353445
# cost_val: 0.8930614
# cost_val: 1.1408817
# cost_val: 0.73613286
# cost_val: 1.0747412
# cost_val: 0.6010292
# cost_val: 0.8930476
# cost_val: 0.7539685
# cost_val: 0.76951456
# cost_val: 0.5457263
# cost_val: 0.7871762
# cost_val: 0.704265
# cost_val: 0.9274602
# cost_val: 0.8848384
# cost_val: 0.9744214
# cost_val: 0.82310104
# cost_val: 1.4001842
# cost_val: 0.6237468
# cost_val: 0.662035
# cost_val: 0.6619378
# cost_val: 0.7513126
# cost_val: 0.78145826
# cost_val: 0.7778975
# cost_val: 1.0903038
# cost_val: 1.1407478
# cost_val: 1.1185306
# cost_val: 0.7687457
# cost_val: 0.80855125
# cost_val: 0.83390236
# cost_val: 0.71778756
# cost_val: 0.89275795
# cost_val: 0.5842056
# cost_val: 0.522492
# cost_val: 0.5066787
# cost_val: 1.1655385
# cost_val: 0.90950227
# cost_val: 0.720605
# cost_val: 0.74998504
# cost_val: 0.6329755
# cost_val: 0.43018857
# cost_val: 0.5331736
# cost_val: 0.6260696
# cost_val: 0.85987234
# cost_val: 0.4702627
# cost_val: 0.5312382
# cost_val: 1.0389936
# cost_val: 0.9070784
# cost_val: 1.0855867
# cost_val: 0.7080008
# cost_val: 0.9056468
# cost_val: 0.9821356
# cost_val: 0.76401544
# cost_val: 0.9756484
# cost_val: 0.83212745
# cost_val: 0.7559201
# cost_val: 0.50738066
# cost_val: 0.5298638
# cost_val: 0.8467802
# cost_val: 1.094282
# cost_val: 0.5258505
# cost_val: 0.5038671
# cost_val: 0.63747877
# cost_val: 0.6893491
# cost_val: 1.1200058
# cost_val: 0.7520105
# cost_val: 0.98486984
# cost_val: 1.1436284
# cost_val: 0.9001711
# cost_val: 0.5765585
# cost_val: 0.7860321
# cost_val: 1.0838735
# cost_val: 0.96438277
# cost_val: 0.70888364
# cost_val: 0.6662783
# cost_val: 0.53791964
# cost_val: 1.5573409
# cost_val: 0.9220694
# cost_val: 0.8590094
# cost_val: 0.9332376
# cost_val: 1.0610163
# cost_val: 0.6890799
# cost_val: 1.1007446
# cost_val: 0.5057686
# cost_val: 0.5306551
# cost_val: 0.9186995
# cost_val: 0.6584562
# cost_val: 0.88311
# cost_val: 1.1031603
# cost_val: 0.83269864
# cost_val: 1.1261312
# cost_val: 0.77370644
# cost_val: 1.0985395
# cost_val: 0.9313974
# cost_val: 0.7159776
# cost_val: 0.5943581
# cost_val: 0.77230406
# cost_val: 0.9282581
# cost_val: 0.9424398
# cost_val: 0.5933227
# cost_val: 1.0893173
# cost_val: 0.9061879
# cost_val: 0.68590456
# cost_val: 0.6813905
# cost_val: 0.6284942
# cost_val: 0.7291399
# cost_val: 0.7308511
# cost_val: 0.5060989
# cost_val: 0.67128474
# cost_val: 0.5870141
# cost_val: 0.88387144
# cost_val: 0.91213554
# cost_val: 0.6588372
# cost_val: 1.0091606
# cost_val: 0.6081514
# cost_val: 1.1357815
# cost_val: 1.0933528
# cost_val: 1.1141982
# cost_val: 0.84872025
# cost_val: 1.0520526
# cost_val: 1.5217975
# cost_val: 1.2868326
# cost_val: 0.8103454
# cost_val: 0.8833126
# cost_val: 0.8479205
# cost_val: 1.1271317
# cost_val: 0.315927
# cost_val: 0.895531
# cost_val: 1.1343334
# cost_val: 0.808226
# cost_val: 0.9952611
# cost_val: 0.8745676
# cost_val: 0.74005866
# cost_val: 0.62627006
# cost_val: 1.1428847
# cost_val: 0.80138606
# cost_val: 0.70276225
# cost_val: 0.9498836
# cost_val: 0.8318256
# cost_val: 0.7135661
# cost_val: 0.58355767
# cost_val: 0.6124111
# cost_val: 0.7298067
# cost_val: 1.1518624
# cost_val: 0.61623186
# cost_val: 0.92946124
# cost_val: 0.81316584
# cost_val: 0.9959854
# cost_val: 1.0088181
# cost_val: 0.43392605
# cost_val: 1.0749161
# cost_val: 0.6214562
# cost_val: 0.63734823
# cost_val: 0.4435546
# cost_val: 0.6369643
# cost_val: 0.71954536
# cost_val: 0.71614766
# cost_val: 1.1086909
# cost_val: 0.8202286
# cost_val: 0.64168787
# cost_val: 0.44901454
# cost_val: 0.7697209
# cost_val: 0.51069415
# cost_val: 0.6783472
# cost_val: 0.94950384
# cost_val: 0.8645434
# cost_val: 0.5978675
# cost_val: 0.92452735
# cost_val: 1.0714258
# cost_val: 0.41292417
# cost_val: 0.83939844
# cost_val: 0.6101582
# cost_val: 0.878752
# cost_val: 0.21483238
# cost_val: 1.061671
# cost_val: 1.0081056
# cost_val: 0.6741082
# cost_val: 0.7843647
# cost_val: 0.6340225
# cost_val: 0.86516345
# cost_val: 0.60904986
# cost_val: 0.86413383
# cost_val: 0.58281
# cost_val: 0.50369346
# cost_val: 0.945683
# cost_val: 0.7901455
# cost_val: 0.78790665
# cost_val: 0.8235312
# cost_val: 0.6042023
# cost_val: 0.7776812
# cost_val: 0.949629
# cost_val: 0.9587424
# cost_val: 0.5831917
# cost_val: 0.5355768
# cost_val: 0.8165721
# cost_val: 0.78138715
# cost_val: 1.2488849
# cost_val: 0.7359357
# cost_val: 0.6828208
# cost_val: 1.0613713
# cost_val: 0.9935542
# cost_val: 0.97756064
# cost_val: 0.5580798
# cost_val: 0.7111569
# cost_val: 0.7494604
# cost_val: 1.1945736
# cost_val: 1.076254
# cost_val: 0.84332067
# cost_val: 1.17748
# cost_val: 0.84665513
# cost_val: 0.7265331
# cost_val: 0.9263415
# cost_val: 0.38269627
# cost_val: 1.3183479
# cost_val: 0.54724115
# cost_val: 0.7655255
# cost_val: 0.66207904
# cost_val: 0.52445316
# cost_val: 0.6233089
# cost_val: 1.1150776
# cost_val: 0.8174498
# cost_val: 0.9170349
# cost_val: 0.8315879
# cost_val: 0.9479282
# cost_val: 0.6304717
# cost_val: 0.6076905
# cost_val: 0.3582716
# cost_val: 1.263349
# cost_val: 0.5751041
# cost_val: 0.81127733
# cost_val: 0.79069036
# cost_val: 0.6847935
# cost_val: 0.83791125
# cost_val: 1.0447061
# cost_val: 0.8408554
# cost_val: 0.9320238
# cost_val: 0.39166543
# cost_val: 0.7523657
# cost_val: 1.081092
# cost_val: 0.7067037
# cost_val: 0.55175585
# cost_val: 0.4513777
# cost_val: 0.8376781
# cost_val: 1.2439201
# cost_val: 0.6974103
# cost_val: 1.0761888
# cost_val: 0.8758833
# cost_val: 0.5445988
# cost_val: 0.3469236
# cost_val: 0.69000274
# cost_val: 0.93820834
# cost_val: 0.70085824
# cost_val: 0.75692976
# cost_val: 0.96183294
# cost_val: 0.6952898
# cost_val: 0.86823344
# cost_val: 1.1744721
# cost_val: 0.68806237
# cost_val: 0.88742113
# cost_val: 0.47764328
# cost_val: 0.9521759
# cost_val: 0.46822885
# cost_val: 0.98692507
# cost_val: 0.9420871
# cost_val: 0.5128019
# cost_val: 0.688933
# cost_val: 0.8100418
# cost_val: 0.7017751
# cost_val: 0.51049685
# cost_val: 0.65048444
# cost_val: 1.430437
# cost_val: 0.48714292
# cost_val: 0.9093091
# cost_val: 1.0871696
# cost_val: 1.0109981
# cost_val: 0.8084287
# cost_val: 0.41645634
# cost_val: 0.86272484
# cost_val: 0.6306837
# cost_val: 0.4748188
# cost_val: 0.69063866
# cost_val: 0.45230758
# cost_val: 0.67924386
# cost_val: 1.2198017
# cost_val: 1.2169731
# cost_val: 0.6417891
# cost_val: 0.91569763
# cost_val: 0.90483993
# cost_val: 1.00946
# cost_val: 0.556142
# cost_val: 0.6006086
# cost_val: 0.70550126
# cost_val: 1.146161
# cost_val: 0.36428693
# cost_val: 0.9114949
# cost_val: 0.89036196
# cost_val: 0.8126665
# cost_val: 1.1357328
# cost_val: 0.92500776
# cost_val: 0.5921397
# cost_val: 0.57200086
# cost_val: 0.61072904
# cost_val: 0.8932455
# cost_val: 0.26818064
# cost_val: 1.2915192
# cost_val: 0.51747245
# cost_val: 0.80426836
# cost_val: 0.6635646
# cost_val: 0.9283802
# cost_val: 0.7778608
# cost_val: 0.9272689
# cost_val: 1.1129832
# cost_val: 0.8602146
# cost_val: 0.87164235
# cost_val: 0.4091624
# cost_val: 0.8440738
# cost_val: 0.6676041
# cost_val: 0.7015223
# cost_val: 0.36507037
# cost_val: 0.713047
# cost_val: 0.29735577
# cost_val: 0.86518687
# cost_val: 0.6089635
# cost_val: 0.8391216
# cost_val: 0.41967988
# cost_val: 0.52778655
# cost_val: 0.7273825
# cost_val: 0.9265287
# cost_val: 0.58554935
# cost_val: 0.5323515
# cost_val: 1.0505679
# cost_val: 0.9613004
# cost_val: 0.94963783
# cost_val: 0.5420363
# cost_val: 0.9556024
# cost_val: 0.7834522
# cost_val: 0.46242306
# cost_val: 0.6542227
# cost_val: 0.9025154
# cost_val: 0.45880547
# cost_val: 0.6724978
# cost_val: 1.1303089
# cost_val: 1.0314656
# cost_val: 1.0555056
# cost_val: 0.84467244
# cost_val: 0.4730222
# cost_val: 0.79813933
# cost_val: 1.0332574
# cost_val: 1.1636173
# cost_val: 0.56813735
# cost_val: 0.613275
# cost_val: 0.46767032
# cost_val: 0.8065432
# cost_val: 1.0177099
# cost_val: 0.4974348
# cost_val: 0.93247986
# cost_val: 0.65054375
# cost_val: 0.67800516
# cost_val: 0.9102941
# cost_val: 0.6774014
# cost_val: 1.1659303
# cost_val: 0.77368754
# cost_val: 1.1771119
# cost_val: 0.55510587
# cost_val: 0.7604166
# cost_val: 0.4851794
# cost_val: 0.6350782
# cost_val: 1.167741
# cost_val: 0.8603559
# cost_val: 1.2395924
# cost_val: 1.1898233
# cost_val: 0.83304566
# cost_val: 0.6792744
# cost_val: 0.7021685
# cost_val: 0.9013805
# cost_val: 0.51012236
# cost_val: 0.87240005
# cost_val: 0.49237555
# cost_val: 0.4055879
# cost_val: 1.0876423
# cost_val: 0.41787437
# cost_val: 0.7921881
# cost_val: 0.5983187
# cost_val: 0.94233584
# cost_val: 0.91559863
# cost_val: 0.94381994
# cost_val: 1.0403743
# cost_val: 1.0266492
# cost_val: 0.8344902
# cost_val: 0.59057087
# cost_val: 0.86793464
# cost_val: 0.67885745
# cost_val: 0.46145332
# cost_val: 0.7441276
# cost_val: 0.41799545
# cost_val: 0.8268481
# cost_val: 0.35298562
# cost_val: 0.9649244
# cost_val: 0.5601024
# cost_val: 0.46775535
# cost_val: 0.58113885
# cost_val: 0.61150193
# cost_val: 0.7632944
# cost_val: 0.40693963
# cost_val: 1.3405979
# cost_val: 0.82494956
# cost_val: 0.8262686
# cost_val: 0.81451535
# cost_val: 0.9332281
# cost_val: 0.42731392
# cost_val: 0.33718207
# cost_val: 0.55704695
# cost_val: 0.93004656
# cost_val: 0.8436796
# cost_val: 0.47115573
# cost_val: 1.2339419
# cost_val: 0.4479944
# cost_val: 0.6375044
# cost_val: 0.63928676
# cost_val: 0.5975283
# cost_val: 0.68593544
# cost_val: 0.82505524
# cost_val: 0.3092522
# cost_val: 0.7860206
# cost_val: 0.6612156
# cost_val: 0.7423164
# cost_val: 0.82490236
# cost_val: 0.4565055
# cost_val: 1.0514824
# cost_val: 0.9697691
# cost_val: 0.84755415
# cost_val: 0.8924152
# cost_val: 0.8243715
# cost_val: 0.8922397
# cost_val: 0.896715
# cost_val: 0.8602635
# cost_val: 0.706841
# cost_val: 0.7587886
# cost_val: 1.1246998
# cost_val: 0.82383883
# cost_val: 0.992706
# cost_val: 0.6854736
# cost_val: 0.4324443
# cost_val: 0.7654913
# cost_val: 0.98921186
# cost_val: 0.86555964
# cost_val: 0.684569
# cost_val: 0.9558452
# cost_val: 0.42722312
# cost_val: 0.6301771
# cost_val: 0.78587914
# cost_val: 0.4682854
# cost_val: 0.5208579
# cost_val: 0.84615517
# cost_val: 0.8888822
# cost_val: 0.5817764
# cost_val: 0.58133614
# cost_val: 0.800176
# cost_val: 0.6515474
# cost_val: 1.0044742
# cost_val: 0.4896608
# cost_val: 1.1042705
# cost_val: 0.67331266
# cost_val: 0.95526046
# cost_val: 0.8784556
# cost_val: 0.65936935
# cost_val: 0.53358406
# cost_val: 0.650038
# cost_val: 0.3530811
# cost_val: 0.56812155
# cost_val: 0.66688836
# cost_val: 0.5934583
# cost_val: 0.58148336
# cost_val: 0.69617516
# cost_val: 0.97634125
# cost_val: 1.1101307
# cost_val: 0.7417101
# cost_val: 0.9908915
# cost_val: 0.63342893
# cost_val: 0.9464628
# cost_val: 0.6771374
# cost_val: 0.8273386
# cost_val: 0.5008897
# cost_val: 0.84268004
# cost_val: 0.7522866
# cost_val: 0.44218162
# cost_val: 0.6339544
# cost_val: 0.85354745
# cost_val: 1.0685732
# cost_val: 0.5069751
# cost_val: 0.8660646
# cost_val: 0.6085744
# cost_val: 0.90972763
# cost_val: 0.6110836
# cost_val: 0.69710165
# cost_val: 0.54992175
# cost_val: 0.4900788
# cost_val: 0.7292946
# cost_val: 0.67848444
# cost_val: 0.6816063
# cost_val: 0.7607097
# cost_val: 0.73039675
# cost_val: 0.8321384
# cost_val: 0.9823666
# cost_val: 0.9394965
# cost_val: 0.9305537
# cost_val: 0.6731093
# cost_val: 0.7928389
# cost_val: 0.9078832
# cost_val: 1.0893838
# cost_val: 0.738299
# cost_val: 0.48776516
# cost_val: 1.0958889
# cost_val: 0.98384756
# cost_val: 0.6090184
# cost_val: 0.57143146
# cost_val: 0.6313379
# cost_val: 0.8258558
# cost_val: 0.30719382
# cost_val: 0.5870626
# cost_val: 0.9839314
# cost_val: 0.91646624
# cost_val: 0.7747939
# cost_val: 0.8157839
# cost_val: 0.9780468
# cost_val: 0.42441672
# cost_val: 1.3021146
# cost_val: 0.7377305
# cost_val: 0.93200433
# cost_val: 0.69139856
# cost_val: 0.53205895
# cost_val: 0.68744993
# cost_val: 0.7178931
# cost_val: 0.45736432
# cost_val: 0.673671
# cost_val: 0.87078553
# cost_val: 0.54644984
# cost_val: 1.2204574
# cost_val: 1.3467517
# cost_val: 0.3861407
# cost_val: 0.44496125
# cost_val: 0.68250793
# cost_val: 1.4759352
# cost_val: 0.6018217
# Epoch: 0004, Cost: 0.782972762
# cost_val: 0.34606814
# cost_val: 0.5728662
# cost_val: 1.0626733
# cost_val: 0.84092957
# cost_val: 0.97348106
# cost_val: 0.557099
# cost_val: 0.6202827
# cost_val: 0.5916631
# cost_val: 0.696759
# cost_val: 0.53538513
# cost_val: 0.860872
# cost_val: 0.7633964
# cost_val: 0.76479423
# cost_val: 0.8136666
# cost_val: 0.80481756
# cost_val: 0.60354155
# cost_val: 0.9279142
# cost_val: 0.53735715
# cost_val: 1.0653583
# cost_val: 0.7091356
# cost_val: 1.3100389
# cost_val: 0.45261356
# cost_val: 1.0410546
# cost_val: 0.36878398
# cost_val: 1.1312975
# cost_val: 1.0339437
# cost_val: 0.85361564
# cost_val: 0.50703484
# cost_val: 0.653934
# cost_val: 0.58193624
# cost_val: 1.1759602
# cost_val: 1.1345491
# cost_val: 0.44911408
# cost_val: 0.4463346
# cost_val: 0.9014381
# cost_val: 0.5332424
# cost_val: 0.72210205
# cost_val: 0.99805
# cost_val: 0.95598733
# cost_val: 0.9387946
# cost_val: 0.38025415
# cost_val: 0.5650488
# cost_val: 1.2117672
# cost_val: 0.56752837
# cost_val: 0.9358049
# cost_val: 0.5333687
# cost_val: 0.7056655
# cost_val: 0.65285295
# cost_val: 0.5670058
# cost_val: 0.8425144
# cost_val: 0.79504716
# cost_val: 0.8216469
# cost_val: 0.86834633
# cost_val: 0.70466715
# cost_val: 0.6191847
# cost_val: 0.56758636
# cost_val: 0.81051415
# cost_val: 0.72180647
# cost_val: 0.5843327
# cost_val: 0.6441282
# cost_val: 1.1375805
# cost_val: 0.69089806
# cost_val: 0.39060363
# cost_val: 0.9099213
# cost_val: 0.59660625
# cost_val: 0.7505977
# cost_val: 0.3871892
# cost_val: 0.78332627
# cost_val: 0.8752573
# cost_val: 0.6703459
# cost_val: 0.9672926
# cost_val: 0.7185445
# cost_val: 0.6942539
# cost_val: 0.8563007
# cost_val: 0.6629084
# cost_val: 1.3786665
# cost_val: 0.43942586
# cost_val: 0.7064178
# cost_val: 0.8825291
# cost_val: 0.5055412
# cost_val: 0.82592756
# cost_val: 0.98153114
# cost_val: 0.95722914
# cost_val: 0.48029625
# cost_val: 0.92785907
# cost_val: 0.7800442
# cost_val: 0.66832703
# cost_val: 0.84702766
# cost_val: 0.5651527
# cost_val: 0.8040698
# cost_val: 0.7621875
# cost_val: 1.2045062
# cost_val: 0.8559999
# cost_val: 0.44508392
# cost_val: 0.52541226
# cost_val: 0.66607714
# cost_val: 0.63155407
# cost_val: 0.58307153
# cost_val: 0.4824982
# cost_val: 0.57721555
# cost_val: 0.8043404
# cost_val: 0.7429894
# cost_val: 0.68790454
# cost_val: 0.7234064
# cost_val: 0.8824096
# cost_val: 0.70131445
# cost_val: 0.4163638
# cost_val: 0.4884874
# cost_val: 0.64593023
# cost_val: 0.6989577
# cost_val: 0.5027524
# cost_val: 0.6117522
# cost_val: 0.6068204
# cost_val: 0.74236596
# cost_val: 0.41675988
# cost_val: 0.76523805
# cost_val: 1.3254433
# cost_val: 0.34005386
# cost_val: 0.73866624
# cost_val: 0.63665533
# cost_val: 0.4378774
# cost_val: 0.59778684
# cost_val: 0.6093124
# cost_val: 0.5451258
# cost_val: 0.59769255
# cost_val: 0.7134592
# cost_val: 0.64441717
# cost_val: 0.58770245
# cost_val: 0.6906822
# cost_val: 0.71271616
# cost_val: 0.7785944
# cost_val: 0.74496317
# cost_val: 0.73460287
# cost_val: 0.6643549
# cost_val: 1.1611727
# cost_val: 0.563032
# cost_val: 0.3226719
# cost_val: 0.6890288
# cost_val: 0.945278
# cost_val: 0.8431006
# cost_val: 1.0653664
# cost_val: 0.42055404
# cost_val: 0.71434927
# cost_val: 0.7590216
# cost_val: 0.9741713
# cost_val: 0.4338127
# cost_val: 0.5497549
# cost_val: 0.73095316
# cost_val: 0.45091397
# cost_val: 0.25761718
# cost_val: 0.74325716
# cost_val: 1.1121674
# cost_val: 0.9018464
# cost_val: 0.79817474
# cost_val: 0.95172143
# cost_val: 0.7706655
# cost_val: 0.59852946
# cost_val: 0.83430624
# cost_val: 1.1808544
# cost_val: 0.8008338
# cost_val: 0.8376301
# cost_val: 0.78360283
# cost_val: 0.88931465
# cost_val: 0.94113874
# cost_val: 0.86426806
# cost_val: 0.90838796
# cost_val: 0.453314
# cost_val: 0.80190736
# cost_val: 0.3594576
# cost_val: 0.80807054
# cost_val: 0.76686615
# cost_val: 0.8490544
# ...
# cost_val: 0.69070125
# cost_val: 0.6945818
# cost_val: 0.6449516
# cost_val: 0.36301577
# cost_val: 0.19417195
# cost_val: 0.5015642
# cost_val: 0.8047963
# cost_val: 0.54291314
# cost_val: 0.66324687
# cost_val: 0.7491475
# cost_val: 0.497971
# cost_val: 0.37897432
# cost_val: 0.47228992
# cost_val: 0.3402792
# cost_val: 0.7292483
# cost_val: 0.26865706
# cost_val: 0.3154546
# cost_val: 0.74287015
# cost_val: 0.24753769
# cost_val: 0.43368286
# cost_val: 0.27424783
# cost_val: 0.40679508
# cost_val: 0.7464401
# cost_val: 0.57941425
# cost_val: 0.2885392
# cost_val: 0.18115675
# cost_val: 0.3347594
# cost_val: 0.77601427
# cost_val: 0.38403594
# cost_val: 0.39264002
# cost_val: 0.25811478
# cost_val: 0.3911076
# cost_val: 0.6445895
# cost_val: 0.36254033
# cost_val: 0.6392918
# cost_val: 0.24556762
# cost_val: 0.5160363
# cost_val: 0.50045717
# cost_val: 0.2861709
# cost_val: 0.2977097
# cost_val: 0.30355012
# cost_val: 0.5656222
# cost_val: 0.33396202
# cost_val: 0.6615409
# cost_val: 0.4610777
# cost_val: 0.23314966
# cost_val: 0.40003768
# cost_val: 0.61465883
# cost_val: 0.532457
# cost_val: 0.43115208
# cost_val: 0.48621067
# cost_val: 0.6125995
# cost_val: 0.39907074
# cost_val: 0.51671576
# cost_val: 0.42637154
# cost_val: 0.3003223
# cost_val: 0.4774073
# cost_val: 0.3939234
# cost_val: 0.39063108
# cost_val: 0.39614892
# cost_val: 0.5651418
# cost_val: 0.5382
# cost_val: 0.43065974
# cost_val: 0.23193549
# cost_val: 0.9425235
# cost_val: 0.30443585
# cost_val: 0.28291005
# cost_val: 0.43170357
# cost_val: 1.0719965
# cost_val: 0.41750133
# cost_val: 0.3360706
# cost_val: 0.30256566
# cost_val: 0.41107187
# cost_val: 0.40342304
# cost_val: 0.7078963
# cost_val: 0.6091863
# cost_val: 0.53537583
# cost_val: 0.35839337
# cost_val: 0.3996576
# cost_val: 0.3569073
# cost_val: 0.5359247
# cost_val: 0.6704625
# cost_val: 0.17240115
# cost_val: 0.23121434
# cost_val: 0.27673796
# cost_val: 0.3184391
# cost_val: 0.3808503
# cost_val: 0.5659583
# cost_val: 0.94706297
# cost_val: 0.70797616
# cost_val: 0.47507042
# cost_val: 0.29415953
# cost_val: 0.33005264
# cost_val: 0.31608477
# cost_val: 0.37208486
# cost_val: 0.22825532
# cost_val: 0.5568444
# cost_val: 0.30815905
# cost_val: 0.34621388
# cost_val: 0.32082173
# cost_val: 0.43816698
# cost_val: 0.342764
# cost_val: 0.625834
# cost_val: 0.838423
# cost_val: 0.4705658
# cost_val: 0.7360159
# cost_val: 0.41332206
# cost_val: 0.46995434
# cost_val: 0.38550457
# cost_val: 0.5886667
# cost_val: 0.40844616
# cost_val: 1.1795671
# cost_val: 0.616086
# cost_val: 0.56705254
# cost_val: 0.28137663
# cost_val: 0.5983953
# cost_val: 0.3980669
# cost_val: 0.30750173
# cost_val: 0.48756284
# cost_val: 0.33563328
# cost_val: 0.33694282
# cost_val: 0.68153626
# cost_val: 0.5810437
# cost_val: 0.46055657
# cost_val: 0.39381382
# cost_val: 0.37559047
# cost_val: 0.516485
# cost_val: 0.31471407
# cost_val: 0.6376854
# cost_val: 0.2994578
# cost_val: 0.3259096
# cost_val: 0.77475953
# cost_val: 0.43159035
# cost_val: 0.68435836
# cost_val: 0.5440402
# cost_val: 0.46376696
# cost_val: 0.37458915
# cost_val: 0.38730362
# cost_val: 0.36515749
# cost_val: 0.44540313
# cost_val: 0.38104916
# cost_val: 0.6377275
# cost_val: 0.3771434
# cost_val: 0.24804379
# cost_val: 0.30767584
# cost_val: 0.41748607
# cost_val: 0.45737863
# cost_val: 0.51949704
# cost_val: 0.93850553
# cost_val: 0.27742568
# cost_val: 0.2941136
# cost_val: 0.65250427
# cost_val: 0.54760695
# cost_val: 0.4389309
# cost_val: 0.54378533
# cost_val: 0.30598512
# cost_val: 0.40643546
# cost_val: 0.34931946
# cost_val: 0.33637455
# cost_val: 0.4508803
# cost_val: 0.36757234
# cost_val: 0.45600826
# cost_val: 0.49827832
# cost_val: 0.54485327
# cost_val: 0.5169001
# cost_val: 0.8169413
# cost_val: 0.68036604
# cost_val: 0.34321433
# cost_val: 0.5145627
# cost_val: 0.5976541
# cost_val: 0.5917171
# cost_val: 0.3856523
# cost_val: 0.4807564
# cost_val: 0.6599739
# cost_val: 0.3979822
# cost_val: 0.3014516
# cost_val: 0.5779801
# cost_val: 0.8934547
# cost_val: 0.6103108
# cost_val: 0.46740162
# cost_val: 0.3763545
# cost_val: 0.5996607
# cost_val: 0.3016613
# cost_val: 0.529507
# cost_val: 1.0071383
# cost_val: 0.9711138
# cost_val: 0.35561818
# cost_val: 0.42007402
# cost_val: 0.36138356
# cost_val: 0.5813711
# cost_val: 0.40173656
# cost_val: 0.5569984
# cost_val: 0.53097135
# cost_val: 0.3817861
# cost_val: 0.37186646
# cost_val: 0.39253548
# cost_val: 0.38045573
# cost_val: 0.6989285
# cost_val: 0.27371988
# cost_val: 0.44610015
# cost_val: 0.5117719
# cost_val: 0.5572495
# cost_val: 0.29219282
# cost_val: 0.6702988
# cost_val: 0.36671475
# cost_val: 0.52790827
# cost_val: 0.51436156
# cost_val: 0.4079641
# cost_val: 0.30485973
# cost_val: 0.43831548
# cost_val: 0.58311045
# cost_val: 0.26347485
# cost_val: 0.44142115
# cost_val: 0.48772645
# cost_val: 0.4540818
# cost_val: 0.5308402
# cost_val: 0.32231593
# cost_val: 0.34445652
# cost_val: 0.43610093
# cost_val: 0.45492095
# cost_val: 0.45728165
# cost_val: 0.5783694
# cost_val: 0.5553665
# Epoch: 0014, Cost: 0.475092032
# cost_val: 0.4651249
# cost_val: 0.3658308
# cost_val: 0.30256063
# cost_val: 0.27862328
# cost_val: 0.3796535
# cost_val: 0.80695593
# cost_val: 0.5734177
# cost_val: 0.2206065
# cost_val: 0.32660088
# cost_val: 0.3753274
# cost_val: 0.49079022
# cost_val: 0.5059738
# cost_val: 0.37324166
# cost_val: 0.46651405
# cost_val: 0.32759652
# cost_val: 0.4919881
# cost_val: 0.8893184
# cost_val: 0.3655697
# cost_val: 0.7580128
# cost_val: 0.65803367
# cost_val: 0.40718788
# cost_val: 0.5120489
# cost_val: 0.62634724
# cost_val: 0.6624503
# cost_val: 0.39273384
# cost_val: 0.2270886
# cost_val: 0.27753866
# cost_val: 0.3119558
# cost_val: 0.5621773
# cost_val: 0.5401894
# cost_val: 0.6759564
# cost_val: 0.36911878
# cost_val: 0.5121245
# cost_val: 0.43393308
# cost_val: 0.5400475
# cost_val: 0.64420044
# cost_val: 0.6334372
# cost_val: 0.48304924
# cost_val: 0.1670837
# cost_val: 0.37436366
# cost_val: 0.4643244
# cost_val: 0.5373582
# cost_val: 0.24144185
# cost_val: 0.6109981
# cost_val: 0.44229722
# cost_val: 0.5117762
# cost_val: 0.39836025
# cost_val: 0.34032878
# cost_val: 0.48202544
# cost_val: 0.47616166
# cost_val: 0.42296058
# cost_val: 0.5592609
# cost_val: 0.4681312
# cost_val: 0.6597679
# cost_val: 0.41860476
# cost_val: 0.45766032
# cost_val: 0.27901265
# cost_val: 0.32651588
# cost_val: 0.651931
# cost_val: 0.29931048
# cost_val: 0.4495384
# cost_val: 0.5540131
# cost_val: 0.4726566
# cost_val: 0.208305
# cost_val: 0.38541847
# cost_val: 0.2761887
# cost_val: 0.47828144
# cost_val: 0.7072097
# cost_val: 0.3026158
# cost_val: 0.34846112
# cost_val: 0.60922223
# cost_val: 0.37927663
# cost_val: 0.5609125
# cost_val: 0.8438582
# cost_val: 0.48052028
# cost_val: 0.5303766
# cost_val: 0.27401015
# cost_val: 0.24052218
# cost_val: 0.41919938
# cost_val: 0.30570188
# cost_val: 0.40754417
# cost_val: 0.28527194
# cost_val: 0.6731514
# cost_val: 0.6119466
# cost_val: 0.4288644
# cost_val: 0.34883064
# cost_val: 0.6177378
# cost_val: 0.3302183
# cost_val: 0.31606328
# cost_val: 0.15868486
# cost_val: 0.2885173
# cost_val: 0.31529573
# cost_val: 0.6371833
# cost_val: 0.23820163
# cost_val: 0.4309141
# cost_val: 0.6292632
# cost_val: 0.3429165
# cost_val: 0.6646334
# cost_val: 0.2812878
# cost_val: 0.38372898
# cost_val: 0.5166451
# cost_val: 0.46009883
# cost_val: 0.82592916
# cost_val: 0.54326975
# cost_val: 0.40504083
# cost_val: 0.40890625
# cost_val: 0.37577403
# cost_val: 0.3958043
# cost_val: 0.4972633
# cost_val: 0.5494053
# cost_val: 0.374368
# cost_val: 0.6181043
# cost_val: 0.39854202
# cost_val: 0.46026868
# cost_val: 0.53501016
# cost_val: 0.2378251
# cost_val: 0.39506465
# cost_val: 0.6536005
# cost_val: 0.39957833
# cost_val: 0.56151026
# cost_val: 0.593688
# cost_val: 0.43513992
# cost_val: 0.50123346
# cost_val: 0.44734368
# cost_val: 0.5172876
# cost_val: 0.33656234
# cost_val: 0.17554843
# cost_val: 0.56139505
# cost_val: 0.24571119
# cost_val: 0.663889
# cost_val: 0.54833055
# cost_val: 0.45938793
# cost_val: 0.47693565
# cost_val: 0.3904227
# cost_val: 0.72996557
# cost_val: 0.43705696
# cost_val: 0.37326762
# cost_val: 0.34157073
# cost_val: 0.4297961
# cost_val: 0.40377426
# cost_val: 0.50803983
# cost_val: 0.5472674
# cost_val: 0.28502235
# cost_val: 0.22216068
# cost_val: 0.420087
# cost_val: 0.38395053
# cost_val: 0.36621732
# cost_val: 0.51643306
# cost_val: 0.35100186
# cost_val: 0.5640302
# cost_val: 0.62113607
# cost_val: 0.49812385
# cost_val: 0.30781335
# cost_val: 0.48595512
# cost_val: 0.69844973
# cost_val: 0.48820722
# cost_val: 0.27281252
# cost_val: 0.45609066
# cost_val: 0.51806664
# cost_val: 0.7639697
# cost_val: 0.31125182
# cost_val: 0.617931
# cost_val: 0.48394263
# cost_val: 0.49176717
# cost_val: 0.4585156
# cost_val: 0.46908322
# cost_val: 0.46033868
# cost_val: 0.40592727
# cost_val: 0.55633473
# cost_val: 0.49391294
# cost_val: 0.60579336
# cost_val: 0.4735139
# cost_val: 0.45494348
# cost_val: 0.58256733
# cost_val: 0.33820832
# cost_val: 0.35651156
# cost_val: 0.5108801
# cost_val: 0.40478265
# cost_val: 0.25299
# cost_val: 0.57870084
# cost_val: 0.30534095
# cost_val: 0.86793524
# cost_val: 0.47758794
# cost_val: 0.35470626
# cost_val: 0.18370402
# cost_val: 0.952629
# cost_val: 0.40907264
# cost_val: 0.36808255
# cost_val: 0.5768292
# cost_val: 0.3682041
# cost_val: 0.8207345
# cost_val: 0.38451356
# cost_val: 0.28106862
# cost_val: 0.4467371
# cost_val: 0.19410576
# cost_val: 0.62273514
# cost_val: 0.5749484
# cost_val: 0.564359
# cost_val: 0.48251972
# cost_val: 0.16698612
# cost_val: 0.6077614
# cost_val: 0.41236946
# cost_val: 0.49941406
# cost_val: 0.45702317
# cost_val: 0.4064877
# cost_val: 0.39341173
# cost_val: 0.39626268
# cost_val: 0.8704333
# cost_val: 0.2684321
# cost_val: 0.38663688
# cost_val: 0.4202576
# cost_val: 0.42149147
# cost_val: 0.51932764
# cost_val: 0.4668605
# cost_val: 0.21304806
# cost_val: 0.46007866
# cost_val: 0.37114212
# cost_val: 0.50239295
# cost_val: 0.5578869
# cost_val: 0.31660497
# cost_val: 0.39077222
# cost_val: 0.47693047
# cost_val: 0.34058854
# cost_val: 0.5206666
# cost_val: 0.63005996
# cost_val: 0.41855714
# cost_val: 0.6065527
# cost_val: 0.5404723
# cost_val: 0.598708
# cost_val: 0.2565453
# cost_val: 0.6588273
# cost_val: 0.57117546
# cost_val: 0.46072894
# cost_val: 0.46871454
# cost_val: 0.478312
# cost_val: 0.48564082
# cost_val: 0.5638483
# cost_val: 0.30750334
# cost_val: 0.42483506
# cost_val: 0.20779389
# cost_val: 0.5218738
# cost_val: 0.4915619
# cost_val: 0.3986622
# cost_val: 0.3549839
# cost_val: 0.51047945
# cost_val: 0.4384677
# cost_val: 0.38275838
# cost_val: 0.37878665
# cost_val: 0.2827994
# cost_val: 0.5963168
# cost_val: 0.6245434
# cost_val: 0.25012407
# cost_val: 0.3687772
# cost_val: 0.28564388
# cost_val: 0.124285184
# cost_val: 0.5618843
# cost_val: 0.3265314
# cost_val: 0.64543843
# cost_val: 0.54707056
# cost_val: 0.4815619
# cost_val: 0.6715737
# cost_val: 0.66540617
# cost_val: 0.45664528
# cost_val: 0.6342813
# cost_val: 0.79040086
# cost_val: 0.19526671
# cost_val: 0.58386683
# cost_val: 0.33038616
# cost_val: 0.59980994
# cost_val: 0.3728149
# cost_val: 0.3404254
# cost_val: 0.50063056
# cost_val: 0.9922352
# cost_val: 0.44186112
# cost_val: 0.5289415
# cost_val: 0.566722
# cost_val: 0.48566628
# cost_val: 0.42416996
# cost_val: 0.3309168
# cost_val: 0.3772255
# cost_val: 0.34339193
# cost_val: 0.7255897
# cost_val: 0.63613373
# cost_val: 0.6513478
# cost_val: 0.4930577
# cost_val: 0.24053106
# cost_val: 0.45637572
# cost_val: 0.5634467
# cost_val: 0.3937827
# cost_val: 0.35936904
# cost_val: 0.38105237
# cost_val: 0.4606326
# cost_val: 0.7691425
# cost_val: 0.42619774
# cost_val: 0.45512885
# cost_val: 0.28725344
# cost_val: 0.36389187
# cost_val: 0.47486797
# cost_val: 0.37250438
# cost_val: 0.3363175
# cost_val: 0.5674643
# cost_val: 0.22553799
# cost_val: 0.3972207
# cost_val: 0.56769866
# cost_val: 0.279358
# cost_val: 0.54412276
# cost_val: 0.37146908
# cost_val: 0.50995517
# cost_val: 0.5200993
# cost_val: 0.64727265
# cost_val: 0.72441345
# cost_val: 0.5501902
# cost_val: 0.39354435
# cost_val: 0.47422233
# cost_val: 0.8898507
# cost_val: 0.3413918
# cost_val: 0.49413612
# cost_val: 0.4654943
# cost_val: 0.3792418
# cost_val: 0.5944782
# cost_val: 0.9855778
# cost_val: 0.41671452
# cost_val: 0.4473644
# cost_val: 0.33188516
# cost_val: 0.47424638
# cost_val: 0.4065707
# cost_val: 0.33403632
# cost_val: 0.2092759
# cost_val: 0.44067392
# cost_val: 0.40785745
# cost_val: 0.43628654
# cost_val: 0.38785672
# cost_val: 0.42557877
# cost_val: 0.53297085
# cost_val: 0.3739193
# cost_val: 0.39573437
# cost_val: 0.49089676
# cost_val: 0.32832965
# cost_val: 0.49108246
# cost_val: 0.6663593
# cost_val: 0.47067454
# cost_val: 0.40924022
# cost_val: 0.4267659
# cost_val: 0.60420674
# cost_val: 0.72779006
# cost_val: 0.44878855
# cost_val: 0.46804357
# cost_val: 0.55696726
# cost_val: 0.23714508
# cost_val: 0.4412764
# cost_val: 0.44295165
# cost_val: 0.6378185
# cost_val: 0.31246245
# cost_val: 0.72932076
# cost_val: 0.8227532
# cost_val: 0.3409961
# cost_val: 0.39871886
# cost_val: 0.37941414
# cost_val: 0.28352174
# cost_val: 0.48671505
# cost_val: 0.4864393
# cost_val: 0.7180934
# cost_val: 0.53025025
# cost_val: 0.7750767
# cost_val: 0.23072453
# cost_val: 0.4868378
# cost_val: 0.6096854
# cost_val: 0.52402097
# cost_val: 0.43519363
# cost_val: 0.28184146
# cost_val: 1.1587191
# cost_val: 0.47674072
# cost_val: 0.4615921
# cost_val: 0.4757082
# cost_val: 0.5787304
# cost_val: 0.37831718
# cost_val: 0.70950145
# cost_val: 0.14748153
# cost_val: 0.5677248
# cost_val: 0.7691406
# cost_val: 0.524722
# cost_val: 0.35962808
# cost_val: 0.41003892
# cost_val: 0.5702475
# cost_val: 0.15259938
# cost_val: 0.2160988
# cost_val: 0.48357886
# cost_val: 0.5864102
# cost_val: 0.35361013
# cost_val: 0.45374492
# cost_val: 0.50827014
# cost_val: 0.6472834
# cost_val: 0.38544747
# cost_val: 0.32693318
# cost_val: 0.79914474
# cost_val: 0.3772093
# cost_val: 0.6629883
# cost_val: 0.2348692
# cost_val: 0.19756304
# cost_val: 0.9276523
# cost_val: 1.0934695
# cost_val: 0.6768671
# cost_val: 0.27325377
# cost_val: 0.3636695
# cost_val: 0.11788382
# cost_val: 0.5696558
# cost_val: 0.86466837
# cost_val: 0.8568883
# cost_val: 0.30255523
# cost_val: 0.488572
# cost_val: 0.4264427
# cost_val: 0.4911566
# cost_val: 0.33133915
# cost_val: 0.4398429
# cost_val: 0.40124822
# cost_val: 0.31693035
# cost_val: 0.39360923
# cost_val: 0.33104733
# cost_val: 0.3356038
# cost_val: 0.41262704
# cost_val: 0.40420237
# cost_val: 0.39210156
# cost_val: 0.37081373
# cost_val: 0.35062692
# cost_val: 0.74371964
# cost_val: 0.65735865
# cost_val: 0.47980866
# cost_val: 0.15680842
# cost_val: 0.31646058
# cost_val: 0.15791312
# cost_val: 0.51354
# cost_val: 0.36377117
# cost_val: 0.32122028
# cost_val: 0.2717037
# cost_val: 0.33468422
# cost_val: 0.37285706
# cost_val: 0.31749707
# cost_val: 0.28733924
# cost_val: 0.3523589
# cost_val: 0.20886347
# cost_val: 0.26987234
# cost_val: 0.36002693
# cost_val: 0.4053184
# cost_val: 0.7251102
# cost_val: 0.61791277
# cost_val: 0.6428855
# cost_val: 0.81378174
# cost_val: 0.40018898
# cost_val: 0.52109766
# cost_val: 0.40494847
# cost_val: 0.5904054
# cost_val: 0.28095326
# cost_val: 0.24518093
# cost_val: 0.5486169
# cost_val: 0.38634726
# cost_val: 0.53352934
# cost_val: 0.9217984
# cost_val: 0.3188271
# cost_val: 0.5155728
# cost_val: 0.639219
# cost_val: 0.3088232
# cost_val: 0.59252596
# cost_val: 0.46077582
# cost_val: 0.704982
# cost_val: 0.38003078
# cost_val: 0.22025362
# cost_val: 0.39913177
# cost_val: 0.46476772
# cost_val: 0.41569495
# cost_val: 0.38657683
# cost_val: 0.21143396
# cost_val: 0.472102
# cost_val: 0.6536352
# cost_val: 0.2806181
# cost_val: 0.47839034
# cost_val: 0.3660145
# cost_val: 0.6568344
# cost_val: 0.38944253
# cost_val: 0.30395493
# cost_val: 0.35110307
# cost_val: 0.5327711
# cost_val: 0.81527257
# cost_val: 0.3272371
# cost_val: 0.45468295
# cost_val: 0.38655987
# cost_val: 0.9803838
# cost_val: 0.43480223
# cost_val: 0.462653
# cost_val: 0.5115594
# cost_val: 0.416945
# cost_val: 0.21683784
# cost_val: 0.6619367
# cost_val: 0.6389315
# cost_val: 0.43366444
# cost_val: 0.5524288
# cost_val: 0.5436954
# cost_val: 0.5357753
# cost_val: 0.34206802
# cost_val: 0.60492253
# cost_val: 0.47724637
# cost_val: 0.6835993
# cost_val: 0.35334828
# cost_val: 0.33704224
# cost_val: 0.773001
# cost_val: 0.5497446
# cost_val: 0.9218224
# cost_val: 0.4412135
# cost_val: 0.4984677
# cost_val: 0.34791848
# cost_val: 0.6859019
# cost_val: 0.46372443
# cost_val: 0.58617735
# cost_val: 0.5039642
# cost_val: 0.37940827
# cost_val: 0.2985158
# cost_val: 0.38362506
# cost_val: 0.24414808
# cost_val: 0.61064214
# cost_val: 0.27396512
# cost_val: 0.6270836
# cost_val: 0.29396018
# cost_val: 0.2846887
# cost_val: 0.49587443
# cost_val: 0.500795
# cost_val: 0.5960344
# cost_val: 0.6026022
# cost_val: 0.5632615
# cost_val: 0.47336784
# cost_val: 0.4556435
# cost_val: 0.15062115
# cost_val: 0.38451672
# cost_val: 0.66092265
# cost_val: 0.5252884
# cost_val: 0.14337988
# cost_val: 0.5160506
# cost_val: 0.5104754
# cost_val: 0.48370034
# cost_val: 0.44688827
# cost_val: 0.18817574
# cost_val: 0.36508223
# cost_val: 0.31398776
# cost_val: 0.36662102
# cost_val: 0.24942744
# cost_val: 0.39325523
# cost_val: 0.5679787
# cost_val: 0.5616182
# cost_val: 0.29941455
# cost_val: 0.3252974
# cost_val: 0.328072
# cost_val: 0.2713442
# Epoch: 0015, Cost: 0.463180485
# Learning finished
# Accuracy: 0.8893
# Label: [0]
# Prediction:  [0]
